# %%
# Out:
# ...
# 100%|██████████| 76.1k/76.1k [00:00<00:00, 43.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/hummaamqaasim/jobs-in-data/versions/6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('jobs_in_data.csv')
df
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4014)

# %%
df_clean = df.drop_duplicates()
df_clean.shape
# Out:
# (5341, 12)

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
df_clean.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  5341.000000    5341.000000    5341.000000
# mean   2022.682082  145814.937839  146258.409099
# std       0.608026   67025.469452   66594.117529
# min    2020.000000   14000.000000   15000.000000
# 25%    2022.000000   97300.000000   98506.000000
# 50%    2023.000000  140000.000000  140000.000000
# 75%    2023.000000  186200.000000  186000.000000
# max    2023.000000  450000.000000  450000.000000

# %%
df['job_title'].unique()
# Out:
# array(['Data DevOps Engineer', 'Data Architect', 'Data Scientist',
#        'Machine Learning Researcher', 'Data Engineer',
#        'Machine Learning Engineer', 'Data Analyst', 'Analytics Engineer',
#        'Applied Scientist', 'BI Developer',
#        'Business Intelligence Engineer', 'Research Scientist',
#        'Research Analyst', 'Research Engineer', 'Data Science Engineer',
#        'Data Quality Analyst', 'Data Product Manager',
#        'Machine Learning Scientist', 'AI Engineer', 'MLOps Engineer',
#        'Deep Learning Engineer', 'Data Modeler', 'Data Product Owner',
#        'Data Science Consultant', 'Business Intelligence Analyst',
#        'AI Developer', 'Data Manager', 'ML Engineer',
#        'Data Science Director', 'Head of Data', 'BI Analyst',
#        'Data Management Analyst', 'Machine Learning Modeler',
#        'Data Specialist', 'BI Data Analyst', 'Data Integration Engineer',
#        'Business Intelligence Manager', 'Data Integration Specialist',
# ...

# %%
df['experience_level'].unique()
# Out:
# array(['Mid-level', 'Senior', 'Executive', 'Entry-level'], dtype=object)

# %%
df['company_size'].unique()
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %%
df_clean['job_category'].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)

# %%
df_clean['experience_level'].unique()
# Out:
# array(['Mid-level', 'Senior', 'Executive', 'Entry-level'], dtype=object)

# %%
df_clean['job_title'].nunique()
# Out:
# 125

# %%
df_clean['job_category'].unique()
# Out:
# array(['Data Engineering', 'Data Architecture and Modeling',
#        'Data Science and Research', 'Machine Learning and AI',
#        'Data Analysis', 'Leadership and Management',
#        'BI and Visualization', 'Data Quality and Operations',
#        'Data Management and Strategy', 'Cloud and Database'], dtype=object)

# %%
df_clean['company_size'].unique()
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %%
df_clean.groupby('experience_level')['salary_in_usd'].mean().sort_values(ascending=False)
# Out:
# experience_level
# Executive      187518.901345
# Senior         161823.012195
# Mid-level      116284.335165
# Entry-level     84711.877500
# Name: salary_in_usd, dtype: float64

# %%
df_clean.groupby('job_category')['salary_in_usd'].mean().sort_values(ascending=False)
# Out:
# job_category
# Machine Learning and AI           170453.221374
# Data Science and Research         157131.039879
# Data Architecture and Modeling    157054.006173
# Cloud and Database                155000.000000
# Leadership and Management         149020.108262
# Data Engineering                  142967.543103
# BI and Visualization              128377.734043
# Data Management and Strategy      107655.836735
# Data Analysis                     106707.058096
# Data Quality and Operations       104586.022222
# Name: salary_in_usd, dtype: float64

# %%
df_clean.groupby('company_size')['salary_in_usd'].mean().sort_values(ascending=False)
# Out:
# company_size
# M    150289.504266
# L    125767.260606
# S     90849.196203
# Name: salary_in_usd, dtype: float64

# %%
df_clean.groupby('job_title')['salary_in_usd'].mean().sort_vp
# Out:
# job_title
# Analytics Engineering Manager     399880.00
# Data Science Tech Lead            375000.00
# Managing Director Data Science    300000.00
# Head of Machine Learning          259000.00
# AWS Data Architect                258000.00
#                                     ...
# Data Management Analyst            56000.00
# Data Operations Specialist         55355.00
# Machine Learning Specialist        55000.00
# Insight Analyst                    47977.75
# Compliance Data Analyst            45000.00
# Name: salary_in_usd, Length: 125, dtype: float64

# %%
df_clean.groupby('work_setting')['salary_in_usd'].mean().sort_values(ascending=False).head(10)
# Out:
# work_setting
# In-person    153629.052523
# Remote       141493.175525
# Hybrid        89108.534392
# Name: salary_in_usd, dtype: float64

# %%
exp_salary = df_clean.groupby('experience_level')['salary_in_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=exp_salary.index, y=exp_salary.values)
plt.title('Average Salary by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Average Salary (USD)')
plt.show()

# %%
cat_salary = df_clean.groupby('job_category')['salary_in_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=cat_salary.values, y=cat_salary.index)
plt.title('Average Salary by Job Category')
plt.xlabel('Average Salary (USD)')
plt.ylabel('Job Category')
plt.show()

# %%
work_salary = df_clean.groupby('work_setting')['salary_in_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=work_salary.index, y=work_salary.values)
plt.title('Average Salary by Work Setting')
plt.xlabel('Work Setting')
plt.ylabel('Average Salary (USD)')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_clean['salary_in_usd'], bins=30, kde=True)
plt.title('Distribution of Salaries')
plt.xlabel('Salary (USD)')
plt.ylabel('Count')
plt.show()

# %%
df_clean.to_csv('cleaned_salaries.csv', index=False)
